# %%
from sklearn.manifold import TSNE
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
(X_mat, Y), (_, _) = mnist.load_data()
print(X_mat.shape)
X = X_mat.reshape((X_mat.shape[0], -1))
print(X.shape)
# Out:
# (60000, 28, 28)
# (60000, 784)

# %%
subset_size = 10000

# %%
# embedding = TSNE(n_components=2).fit_transform(X[:subset_size, :])
embedding = np.load('tsne_emb.npy')

# %%
print(embedding.shape)
# Out:
# (10000, 2)

# %%
colors = ['r','g','b','brown','aqua', 'orange', 'pink', 'purple', 'lightgreen', 'grey']
# 0: red
# 1: green
# 2: blue
# 3: brown
# 4: aqua
# 5: orange
# 6: pink
# 7: purple
# 8: lightgreen
# 9: grey

# %%
c_Y = [colors[c] for c in Y]
print(len(c_Y))
# Out:
# 60000

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=c_Y[:subset_size], s=1)
plt.plot()
# Out:
# []

# %%
# np.save('tsne_emb', embedding)
