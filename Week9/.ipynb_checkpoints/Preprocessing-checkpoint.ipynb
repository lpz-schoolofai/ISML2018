# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('TimeSeries/international-airline-passengers.csv')

# %%
data = data.drop(['Month'], axis=1)
data.columns = [0]

# %%
data
# Out:
#          0
# 0    112.0
# 1    118.0
# 2    132.0
# 3    129.0
# 4    121.0
# 5    135.0
# 6    148.0
# 7    148.0
# 8    136.0
# 9    119.0
# 10   104.0
# 11   118.0
# 12   115.0
# 13   126.0
# 14   141.0
# 15   135.0
# 16   125.0
# 17   149.0
# 18   170.0
# 19   170.0
# 20   158.0
# 21   133.0
# 22   114.0
# 23   140.0
# 24   145.0
# 25   150.0
# 26   178.0
# 27   163.0
# 28   172.0
# 29   178.0
# ..     ...
# 115  505.0
# 116  404.0
# 117  359.0
# 118  310.0
# 119  337.0
# 120  360.0
# 121  342.0
# 122  406.0
# 123  396.0
# 124  420.0
# 125  472.0
# 126  548.0
# 127  559.0
# 128  463.0
# 129  407.0
# 130  362.0
# 131  405.0
# 132  417.0
# 133  391.0
# 134  419.0
# 135  461.0
# 136  472.0
# 137  535.0
# 138  622.0
# 139  606.0
# 140  508.0
# 141  461.0
# 142  390.0
# 143  432.0
# 144    NaN
#
# [145 rows x 1 columns]

# %%
data_array = data.as_matrix()[:-1]
# %xdel data

# %%
plt.plot(data_array)
plt.show()
print(data_array.shape)
# Out:
# (144, 1)

# %%
np.random.seed(7)

# %%
orig = data_array.copy()
scaler = MinMaxScaler(feature_range=(0, 1))
data_array = scaler.fit_transform(data_array)

# %%
plt.plot(data_array)
plt.show()
print(data_array.shape)
# Out:
# (144, 1)

# %%
#80% del dataset = ceil( 144*0.8 ) = 116 + 1
#10% CV = 14 + 1
#10% test = 14

# %%
train_array = data_array[0:117]
cv_array = data_array[116:131]
test_array = data_array[131:144]

print(train_array.shape)
print(cv_array.shape)
print(test_array.shape)
print('---------------------')
print(train_array[116], cv_array[0])
print(cv_array[13], test_array[0])
# Out:
# (117, 1)
# (15, 1)
# (13, 1)
# ---------------------
# [0.57915058] [0.57915058]
# [0.58494208] [0.58108108]

# %%
def create_dataset(data):
    dataX, dataY = [], []
    for i in range(len(data)-1):
        a = data[i:(i+1), 0]
        dataX.append(a)
        dataY.append(data[i + 1, 0])
    return np.array(dataX), np.array(dataY)

# %%
X_train, Y_train = create_dataset(train_array)
X_cross_val, Y_cross_val = create_dataset(cv_array)
X_test, Y_test = create_dataset(test_array)

print(X_train.shape, Y_train.shape)
print(X_cross_val.shape, Y_cross_val.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (116, 1) (116,)
# (14, 1) (14,)
# (12, 1) (12,)

# %%
np.save('TimeSeries/orig', orig)

np.save('TimeSeries/X_train', X_train)
np.save('TimeSeries/Y_train', Y_train)

np.save('TimeSeries/X_cross_val', X_cross_val)
np.save('TimeSeries/Y_cross_val', Y_cross_val)

np.save('TimeSeries/X_test', Y_test)
np.save('TimeSeries/Y_test', Y_test)
